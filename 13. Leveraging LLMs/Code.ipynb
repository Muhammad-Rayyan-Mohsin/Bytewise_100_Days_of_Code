# %%
import pandas as pd
#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("car_reviews.csv", sep=';')
df.tail()
# Out:
#                                               Review     Class
# 0  I am very satisfied with my 2014 Nissan NV SL....  POSITIVE
# 1  The car is fine. It's a bit loud and not very ...  NEGATIVE
# 2  My first foreign car. Love it, I would buy ano...  POSITIVE
# 3  I've come across numerous reviews praising the...  NEGATIVE
# 4  I've been dreaming of owning an SUV for quite ...  POSITIVE

# %%
df['Class'] = df['Class'].apply(lambda x: 1 if x == 'POSITIVE' else 0)

# %%
df['pred'] = ''
df
# Out:
#                                               Review  Class pred
# 0  I am very satisfied with my 2014 Nissan NV SL....      1
# 1  The car is fine. It's a bit loud and not very ...      0
# 2  My first foreign car. Love it, I would buy ano...      1
# 3  I've come across numerous reviews praising the...      0
# 4  I've been dreaming of owning an SUV for quite ...      1

# %%
# import nltk
# nltk.download('punkt')

# import re
# from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer

# # Ensure you have stopwords and wordnet downloaded as well
# nltk.download('stopwords')
# nltk.download('wordnet')

# # Initialize lemmatizer and stopwords
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# # Define preprocessing function
# def preprocess_text(text):
#     # Convert text to lowercase
#     text = text.lower()

#     # Remove non-alphabetical characters
#     text = re.sub(r'[^a-zA-Z\s]', '', text)

#     # Tokenize the text
#     tokens = word_tokenize(text)

#     # Remove stopwords and lemmatize
#     processed_tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]

#     return ' '.join(processed_tokens)

# # Apply preprocessing to the 'Review' column
# df['Processed_Review'] = df['Review'].apply(preprocess_text)

# # Display the first few rows to verify the preprocessing
# print(df[['Review', 'Processed_Review']].head())

# %%
df
# Out:
#                                               Review  Class pred
# 0  I am very satisfied with my 2014 Nissan NV SL....      1
# 1  The car is fine. It's a bit loud and not very ...      0
# 2  My first foreign car. Love it, I would buy ano...      1
# 3  I've come across numerous reviews praising the...      0
# 4  I've been dreaming of owning an SUV for quite ...      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  5 non-null      object
#  1   Class   5 non-null      int64
#  2   pred    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df.columns
# Out:
# Index(['Review', 'Class', 'pred'], dtype='object')

# %%
# # prompt: Remove Reviw column and place pred column at the last

# df = df.drop('Review', axis=1)
# df = df[['Processed_Review', 'Class', 'pred']]
df
# Out:
#                                               Review  Class pred
# 0  I am very satisfied with my 2014 Nissan NV SL....      1
# 1  The car is fine. It's a bit loud and not very ...      0
# 2  My first foreign car. Love it, I would buy ano...      1
# 3  I've come across numerous reviews praising the...      0
# 4  I've been dreaming of owning an SUV for quite ...      1

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

from google.colab import userdata

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
json_data = df[['Review','Class', 'pred']].to_json(orient='records')
data1 = json_data

print(json_data)
# Out:
# [{"Review":"I am very satisfied with my 2014 Nissan NV SL. I use this van for my business deliveries and personal use. Camping, road trips, etc. We dont have any children so I store most of the seats in my warehouse. I wanted the passenger van for the rear air conditioning. We drove our van from Florida to California for a Cross Country trip in 2014. We averaged about 18 mpg. We drove thru a lot of rain and It was a very comfortable and stable vehicle. The V8 Nissan Titan engine is a 500k mile engine. It has been tested many times by delivery and trucking companies. This is why Nissan gives you a 5 year or 100k mile bumper to bumper warranty. Many people are scared about driving this van because of its size. But with front and rear sonar sensors, large mirrors and the back up camera. It is easy to drive. The front and rear sensors also monitor the front and rear sides of the bumpers making it easier to park close to objects. Our Nissan NV is a Tow Monster. It pulls our 5000 pound tra
# ...

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# ...

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# ...

# %%
import json

json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                               Review  Class  pred
# 0  I am very satisfied with my 2014 Nissan NV SL....      1     1
# 1  The car is fine. It's a bit loud and not very ...      0     0
# 2  My first foreign car. Love it, I would buy ano...      1     1
# 3  I've come across numerous reviews praising the...      0     0
# 4  I've been dreaming of owning an SUV for quite ...      1     1

# %%
from sklearn.metrics import accuracy_score, f1_score

accuracy = accuracy_score(df_sample['Class'], df_sample['pred'])
f1 = f1_score(df_sample['Class'], df_sample['pred'])

print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Accuracy: 1.0
# F1 Score: 1.0

# %%
prompt = f"""
You are an expert translator who is good at translating customer reviews from English to Spanish and classifying them into Positive (label=1) and Negative (label=0) sentiments.

Help me translate and classify customer reviews.

Customer reviews in English are provided between three backticks, and the translated Spanish reviews should be returned in the same format.

In your output, only return the JSON code with updated Spanish translations and sentiment labels under 'pred_label' between three backticks.

Please ensure the JSON code format remains unchanged.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert translator who is good at translating customer reviews from English to Spanish and classifying them into Positive (label=1) and Negative (label=0) sentiments.
#
# Help me translate and classify customer reviews.
#
# Customer reviews in English are provided between three backticks, and the translated Spanish reviews should be returned in the same format.
#
# In your output, only return the JSON code with updated Spanish translations and sentiment labels under 'pred_label' between three backticks.
#
# Please ensure the JSON code format remains unchanged.
#
# ```
#
# ...

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# ...

# %%
import json

json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                               Review  Class  pred
# 0  I am very satisfied with my 2014 Nissan NV SL....      1     1
# 1  El coche está bien. Es un poco ruidoso y no mu...      0     0
# 2  Mi primer coche extranjero. Me encanta, compra...      1     1
# 3  Me he encontrado con numerosas críticas que el...      0     0
# 4  He estado soñando con tener un SUV durante bas...      1     1

# %%
df
# Out:
#                                               Review  Class pred
# 0  I am very satisfied with my 2014 Nissan NV SL....      1
# 1  The car is fine. It's a bit loud and not very ...      0
# 2  My first foreign car. Love it, I would buy ano...      1
# 3  I've come across numerous reviews praising the...      0
# 4  I've been dreaming of owning an SUV for quite ...      1

# %%
from nltk.translate.bleu_score import sentence_bleu

english_reviews = df['Review'].tolist()[:2]
spanish_reviews = df_sample['Review'].tolist()[:2]

bleu_scores = []
for i in range(2):
  reference = [word_tokenize(english_reviews[i])]
  candidate = word_tokenize(spanish_reviews[i])
  score = sentence_bleu(reference, candidate)
  bleu_scores.append(score)

for i, score in enumerate(bleu_scores):
  print(f"BLEU score for review {i+1}: {score}")
# Out:
# BLEU score for review 1: 0.5969898038095771
# BLEU score for review 2: 7.417286788535422e-79

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

# Load the model and tokenizer
model_name = "deepset/minilm-uncased-squad2"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)

review_index = 3  # Example index
context = df.loc[review_index, 'Review']

question = "What did he like?"

QA_input = {'question': question, 'context': context}

answer = nlp(QA_input)['answer']

print("Context:", context)
print("Question:", question)
print("Answer:", answer)
df.loc[review_index, 'Review']
# Out:
# Some weights of the model checkpoint at deepset/minilm-uncased-squad2 were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
prompt = f"""
•	Summarize the last review in the dataset, into approximately 50-55 tokens long. Store it in the variable summarized_text.

```
{data}
```
"""

print(prompt)
# Out:
# •	Summarize the last review in the dataset, into approximately 50-55 tokens long. Store it in the variable summarized_text.
#
# ```
# ...

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

from google.colab import userdata

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content(prompt)

print(response.text)
df.iloc[-1, 0]
summarized_text = response.text
# Out:
# ```python
# summarized_text = "The reviewer expresses overall satisfaction with their 2014 Nissan NV SL for business and personal use. They mention its comfortable ride, spacious cabin, and powerful engine. Despite its size, they find it easy to drive due to its sensors and cameras. They also appreciate the Nissan Titan engine's reliability. The reviewer would appreciate amber side marker lights on the mirrors."
# ```
# ...
